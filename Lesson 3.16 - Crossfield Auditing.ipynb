# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
In this problem set you work with cities infobox data, audit it, come up with a cleaning idea and then clean it up.

If you look at the full city data, you will notice that there are couple of values that seem to provide
the same information in different formats: "point" seems to be the combination of "wgs84_pos#lat" and "wgs84_pos#long".
However we do not know if that is the case and should check if they are equivalent.

Finish the function check_loc(). It will recieve 3 strings, first will be the combined value of "point" and then the
"wgs84_pos#" values separately. You have to extract the lat and long values from the "point" and compare
to the "wgs84_pos# values and return True or False.

Note that you do not have to fix the values, just determine if they are consistent. To fix them in this case
you would need more information. Feel free to discuss possible strategies for fixing this on the discussion forum.

The rest of the code is just an example on how this function can be used.
Changes to "process_file" function will not be take into account.
"""
import csv
import pprint
import pandas as pd

CITIES = 'cities.csv'

def check_loc(point, lat, longi):
    # YOUR CODE HERE
    point = point.split(" ")
    if point[0] == lat and point[1] == longi:
        return True
    else retunr False


def process_file(filename):
    data = []
    with open(filename, "r") as f:
        reader = csv.DictReader(f)
        #skipping the extra matadata
        for i in range(3):
            l = reader.next()
        # processing file
        for line in reader:
            # calling your function to check the location
            result = check_loc(line["point"], line["wgs84_pos#lat"], line["wgs84_pos#long"])
            if not result:
                print "{}: {} != {} {}".format(line["name"], line["point"], line["wgs84_pos#lat"], line["wgs84_pos#long"])
            data.append(line)

    return data


def test():
    assert check_loc("33.08 75.28", "33.08", "75.28") == True
    assert check_loc("44.57833333333333 -91.21833333333333", "44.5783", "-91.2183") == False

if __name__ == "__main__":
    test()
# Out:
# 33.08 75.28
# 33.08 75.28
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-aa998ddeccd3> in <module>()
#      55
#      56 if __name__ == "__main__":
# ---> 57     test()
#
# <ipython-input-11-aa998ddeccd3> in test()
#      51
#      52 def test():
# ---> 53     assert check_loc("33.08 75.28", "33.08", "75.28") == True
#      54     assert check_loc("44.57833333333333 -91.21833333333333", "44.5783", "-91.2183") == False
#      55
#
# AssertionError:

# %%
df = pd.read_csv("cities.csv")

# %%
pprint.pprint(df.head())
# Out:
#                                            URI  \
# 0                                          URI
# 1                                          URI
# 2          http://www.w3.org/2002/07/owl#Thing
# 3              http://dbpedia.org/resource/Kud
# 4  http://dbpedia.org/resource/Kuju,_Hazaribag
#
#                              rdf-schema#label  \
# 0  http://www.w3.org/2000/01/rdf-schema#label
# 1                            XMLSchema#string
# 2     http://www.w3.org/2001/XMLSchema#string
# 3                                         Kud
# 4                              Kuju Hazaribag
#
#                                   rdf-schema#comment  \
# 0       http://www.w3.org/2000/01/rdf-schema#comment
# 1                                   XMLSchema#string
# 2            http://www.w3.org/2001/XMLSchema#string
# 3  Kud is a town and a notified area committee in...
# 4  Kuju is a census town in Ramgarh district in t...
#
#                         administrativeDistrict_label  \
# 0  http://dbpedia.org/ontology/administrativeDist...
# 1                                   XMLSchema#string
# 2            http://www.w3.org/2001/XMLSchema#string
# 3                                                NaN
# 4                                                NaN
#
#                               administrativeDistrict  \
# 0  http://dbpedia.org/ontology/administrativeDist...
# 1                                     PopulatedPlace
# 2         http://dbpedia.org/ontology/PopulatedPlace
# 3                                                NaN
# 4                                                NaN
#
#                               anthem_label  \
# 0       http://dbpedia.org/ontology/anthem
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                      NaN
# 4                                      NaN
#
#                                anthem  \
# 0  http://dbpedia.org/ontology/anthem
# 1                                Work
# 2    http://dbpedia.org/ontology/Work
# 3                                 NaN
# 4                                 NaN
#
#                                       area  \
# 0         http://dbpedia.org/ontology/area
# 1                         XMLSchema#double
# 2  http://www.w3.org/2001/XMLSchema#double
# 3                                      NaN
# 4                                      NaN
#
#                                   areaCode  \
# 0     http://dbpedia.org/ontology/areaCode
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                      NaN
# 4                                      NaN
#
#                                   areaLand  \
# 0     http://dbpedia.org/ontology/areaLand
# 1                         XMLSchema#double
# 2  http://www.w3.org/2001/XMLSchema#double
# 3                                      NaN
# 4                                      NaN
#
#                     ...                     \
# 0                   ...
# 1                   ...
# 2                   ...
# 3                   ...
# 4                   ...
#
#                          22-rdf-syntax-ns#type_label  \
# 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1                                   XMLSchema#string
# 2            http://www.w3.org/2001/XMLSchema#string
# 3  {city|place|populated place|municipality|City|...
# 4  {city|place|populated place|municipality|City|...
#
#                                22-rdf-syntax-ns#type  \
# 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1                                          owl#Class
# 2                http://www.w3.org/2002/07/owl#Class
# 3  {http://dbpedia.org/ontology/City|http://dbped...
# 4  {http://dbpedia.org/ontology/City|http://dbped...
#
#                                  wgs84_pos#lat  \
# 0  http://www.w3.org/2003/01/geo/wgs84_pos#lat
# 1                              XMLSchema#float
# 2       http://www.w3.org/2001/XMLSchema#float
# 3                                        33.08
# 4                                        23.72
#
#                                  wgs84_pos#long  \
# 0  http://www.w3.org/2003/01/geo/wgs84_pos#long
# 1                               XMLSchema#float
# 2        http://www.w3.org/2001/XMLSchema#float
# 3                                         75.28
# 4                                          85.5
#
#                            depiction_label  \
# 0      http://xmlns.com/foaf/0.1/depiction
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                      NaN
# 4                                      NaN
#
#                              depiction  \
# 0  http://xmlns.com/foaf/0.1/depiction
# 1                            owl#Thing
# 2  http://www.w3.org/2002/07/owl#Thing
# 3                                  NaN
# 4                                  NaN
#
#                             homepage_label  \
# 0       http://xmlns.com/foaf/0.1/homepage
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                      NaN
# 4                                      NaN
#
#                               homepage  \
# 0   http://xmlns.com/foaf/0.1/homepage
# 1                            owl#Thing
# 2  http://www.w3.org/2002/07/owl#Thing
# 3                                  NaN
# 4                                  NaN
#
#                                       name  \
# 0           http://xmlns.com/foaf/0.1/name
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                      Kud
# 4                                     Kuju
#
#                                       nick
# 0           http://xmlns.com/foaf/0.1/nick
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 99 columns]
